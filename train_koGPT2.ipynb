# %% [markdown]
# <a href="https://colab.research.google.com/github/jinbaaaaaang/oss-siot/blob/main/train_koGPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch accelerate scikit-learn

# %%
# %cd /content

# %%
# !git clone https://github.com/jinbaaaaaang/oss-siot.git
# %cd siot-OSS/backend

# %%
exec(open('train_kogpt2_colab.py').read())
# Out:
# ...
# Google Colab에서 koGPT2 모델 k-fold 교차 검증 학습
# ...
#
# ✅ GPU 사용 가능: Tesla T4
# 💡 GPU 모드로 학습을 진행합니다.
#    CUDA 오류가 발생하면 런타임을 재시작하세요: 런타임 → 런타임 다시 시작
#
# ...
# [KPoeM 데이터셋 다운로드]
#   - 소스: Hugging Face (AKS-DHLAB/KPoEM)
#   - 최대 개수: 100
# ...
#
# [다운로드 시도] AKS-DHLAB/KPoEM...
# ✅ 데이터셋 로드 성공: 615개 샘플
# ✅ 100개 데이터 변환 완료
#
# ...
# [k-fold 교차 검증 시작]
#   - 데이터 개수: 100
#   - Fold 개수: 5
# ...
#
# ✅ GPU 사용 가능 (디바이스 1개 감지)
# 💡 GPU 모드로 학습을 진행합니다.
#
# ...
# [Fold 1/5]
#   - Train: 80개
#   - Test: 20개
# ...
#
#
# ...
# [koGPT2 모델 학습 시작]
#   - 학습 데이터: 80개
#   - Epochs: 2
#   - Learning Rate: 5e-05
#   - Batch Size: 4
#   - Gradient Accumulation Steps: 4
# ...
#
# [1/5] 모델 및 토크나이저 로딩: skt/kogpt2-base-v2
#   - 초기 vocab 크기: 51201 (base: 51200)
#   ⚠️ 토크나이저 로드 시 이미 추가 토큰 1개가 포함되어 있습니다.
#   🔧 토크나이저를 base_vocab_size에 맞춰 조정합니다...
#   - Base vocab size: 51200
#   - Actual vocab size (len(tokenizer)): 51201
#   - Pad token ID: 51200
#   - EOS token ID: 51200
#   ⚠️ 추가 토큰: 1개 (모델 리사이즈 필요)
#   - 디바이스: CUDA
#   - GPU 이름: Tesla T4
#   - GPU 메모리: 14.7GB
# ...

# %%
exec(open('/find_model_folder.py').read())
# Out:
# 🔍 모델 폴더 검색 중... (20251109_08로 시작하는 모델만)
#
# 현재 디렉토리: /content
#
# 📁 검색 결과:
#
# ✅ 5개의 kogpt2 관련 폴더를 찾았습니다:
#
#   1. kogpt2_finetuned_fold2_20251109_084658
#      경로: /content/kogpt2_finetuned_fold2_20251109_084658
#      Fold 개수: 0
#
#   2. kogpt2_finetuned_fold5_20251109_085348
#      경로: /content/kogpt2_finetuned_fold5_20251109_085348
#      Fold 개수: 0
#
#   3. kogpt2_finetuned_fold4_20251109_085149
#      경로: /content/kogpt2_finetuned_fold4_20251109_085149
#      Fold 개수: 0
#
#   4. kogpt2_finetuned_fold1_20251109_084450
#      경로: /content/kogpt2_finetuned_fold1_20251109_084450
#      Fold 개수: 0
#
#   5. kogpt2_finetuned_fold3_20251109_084825
#      경로: /content/kogpt2_finetuned_fold3_20251109_084825
#      Fold 개수: 0
#
# ✅ 5개의 직접 fold 폴더를 찾았습니다:
#
#   1. kogpt2_finetuned_fold2_20251109_084658
#      경로: /content/kogpt2_finetuned_fold2_20251109_084658
#   2. kogpt2_finetuned_fold5_20251109_085348
#      경로: /content/kogpt2_finetuned_fold5_20251109_085348
# ...

# %%
exec(open('/evaluate_folds_colab.py').read())
# Out:
# ...
# k-fold 모델 성능 평가
# ...
#
# ✅ GPU 사용: Tesla T4
#
# [0/4] 모델 폴더 찾기...
# ⚠️ ./kogpt2_finetuned 폴더를 찾을 수 없습니다. 자동 검색 중...
#
# 📁 찾은 폴더:
#   1. kogpt2_finetuned_fold2_20251109_084658
#   2. kogpt2_finetuned_fold5_20251109_085348
#   3. kogpt2_finetuned_fold4_20251109_085149
#   4. kogpt2_finetuned_fold1_20251109_084450
#   5. kogpt2_finetuned_fold1_20251109_071547
#   6. kogpt2_finetuned_fold2_20251109_071907
#   7. kogpt2_finetuned_fold4_20251109_072244
#   8. kogpt2_finetuned_fold3_20251109_072129
#   9. kogpt2_finetuned_fold5_20251109_072539
#   10. kogpt2_finetuned_fold3_20251109_084825
#
# 💡 여러 폴더를 찾았습니다. 첫 번째 폴더를 사용합니다.
# ✅ 선택: kogpt2_finetuned_fold2_20251109_084658
# ✅ 모델 폴더: /content/kogpt2_finetuned_fold2_20251109_084658
#
# [1/4] 데이터 로드 중...
#
# ...
# [KPoeM 데이터셋 다운로드]
#   - 최대 개수: 100
# ...
#
# ✅ 100개 데이터 로드 완료
#
# [2/4] k-fold 분할 중...
#
# 🔍 Fold 모델 검색 중...
# ✅ 5개의 fold 모델을 찾았습니다:
#   - Fold 1: kogpt2_finetuned_fold1_20251109_084450
#   - Fold 2: kogpt2_finetuned_fold2_20251109_084658
# ...

# %%
import shutil
from google.colab import files

fold_folder = ""

# 폴더를 직접 압축
shutil.make_archive(fold_folder, 'zip', fold_folder)

# 다운로드
files.download(f"{fold_folder}.zip")
